# %%
m.save("map.html")

# %%
import pandas
import os
import folium
from folium import IFrame
import base64

filelist = []
for photos in os.listdir(os.curdir):
    if photos.endswith(".jpg"):
            filelist.append(photos)

namelist = ["Brunssumerheide","Schutterspark","Trap Wilhelminaberg",
            "Preuverie Auwt Gäöl","WINDRAAK31","Omnomnom Sittard",
            "Café aan de Müehle","De Hompesche Molen"]
latlist = [50.9285,50.9461,50.8862,
           50.9305,50.9727,50.9992,
           51.0380,51.1411]
lonlist = [5.9993,5.9851,6.0269,
           5.7384,5.8893,5.8639,
           5.9873,5.830]
typelist = ["tree","tree","tree",
            "food","food","food",
            "city","city"]

index = range(1,len(namelist)+1)
columns = ['Filename','Filepic','Lat','Lon','Type']         
df = pandas.DataFrame(index=index, columns=columns)

df['Filename']=namelist
df['Filepic']=filelist
df['Lat']=latlist
df['Lon']=lonlist
df['Type']=typelist

#Create map object:
m=folium.Map(location=[51.0, 5.8],zoom_start=10)

#Create iFrame tree:
for lat,lon,Filepic,Filename,Type in zip(df['Lat'],df['Lon'],df['Filepic'],df['Filename'],df['Type']):
    encoded = base64.b64encode(open(Filepic, 'rb').read())
    html = '<img src="data:image/jpeg;base64,{}">'.format
    Filename = '<h3>{}</h3>'.format(Filename)
    iframe = IFrame(Filename + html(encoded.decode('UTF-8')), width=220, height=260)
    popup = folium.Popup(iframe, max_width=1000)
    if Type == 'tree':
        icon = folium.Icon(color="green", icon="tree-conifer")
    elif Type == 'food':
        icon = folium.Icon(color="red", icon="cutlery")
    elif Type == 'city':
        icon = folium.Icon(color="blue", icon="tower")    
    marker = folium.Marker(location=[lat, lon], popup=popup, icon=icon)
    marker.add_to(m)
    
print(df)
m
# Out:
#               Filename                    Filepic      Lat     Lon  Type
# 1      Brunssumerheide     1_1brunssumerheide.jpg  50.9285  5.9993  tree
# 2        Schutterspark       1_2schutterspark.jpg  50.9461  5.9851  tree
# 3  Trap Wilhelminaberg  1_3trapwilhelminaberg.jpg  50.8862  6.0269  tree
# 4  Preuverie Auwt Gäöl         2_1placeholder.jpg  50.9305  5.7384  food
# 5           WINDRAAK31         2_2placeholder.jpg  50.9727  5.8893  food
# 6     Omnomnom Sittard         2_3placeholder.jpg  50.9992  5.8639  food
# 7   Café aan de Müehle      3_1cafeaandemuhle.jpg  51.0380  5.9873  city
# 8   De Hompesche Molen      3_2hompeschemolen.jpg  51.1411  5.8300  city
# ...
